# %% [markdown]
# #1. Loading the data

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2962ed80-48f6-4820-a792-d295aac7288e" name="files[]" multiple disabled />
#      <output id="result-2962ed80-48f6-4820-a792-d295aac7288e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving handlenull.xlsx to handlenull.xlsx
# ...

# %%
data=pd.read_excel('handlenull.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 35 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    187 non-null    int64
#  1   age_codes                                     185 non-null    float64
#  2   Age                                           185 non-null    float64
#  3   gender_code                                   184 non-null    float64
#  4   Door to needle time                           185 non-null    float64
#  5   door-door time_code                           185 non-null    float64
#  6   Neurological Deficit_code                     185 non-null    float64
#  7   CODING WINDOW                                 185 non-null    float64
#  8   NIHSS on admission                            185 non-null    float64
# ...

# %%
print(list(data.columns))
# Out:
# ['Unnamed: 0', 'age_codes', 'Age', 'gender_code', 'Door to needle time ', 'door-door time_code', 'Neurological Deficit_code ', 'CODING WINDOW ', 'NIHSS on admission', 'NIHSS admission_code', 'MRS', 'Hyper tension ', 'DM', 'blood pressure_code', 'Blood Sugar at the time of admission (mg/dl)', 'blood sugar_code', 'CODING ANT. POST. COMBINATION', 'LARGE Vs SMALL ARTERY', 'HAGE', ' Dose of Actilyse/ Weight(in gms)', 'NIHSS on admission.1', 'NIHSS on discharge/MRS_codes_improved or not', 'NIHSS after 1 hr', '  NIHSS after 6 hrs', 'complications_code', 'outcome', '2D ECHO', 'MRA (BRAIN/NECK)', 'CAROTID DOPPLER ', 'OTHER CO- MORBIDITY', 'ADDICTION', 'CODE SMOKER ', 'History of Stroke', 'systolic', 'diastolic']

# %% [markdown]
# #2. Identifying the type of variables

# %% [markdown]
# ####Variables :
#
#
# *   Numerical :
#   'Age',
#
#   'Door to needle time ',
#
#   'NIHSS on admission',
#
#   'Blood Sugar at the time of admission (mg/dl)',
#
#   ' Dose of Actilyse/ Weight(in gms)',
#
#   'NIHSS on admission.1',
#
#   'NIHSS after 1 hr',
#
#   '  NIHSS after 6 hrs',
# *   Categorical :
# 'age_codes',
#
#  'gender_code',
#
#  'door-door time_code',
#
#  'Neurological Deficit_code ',
#
#  'CODING WINDOW ',
#
#  'NIHSS admission_code',
#
#  'MRS',
#
#  'Hyper tension ',
#
#  'DM',
#
#  'blood pressure_code',
#
#  'blood sugar_code',
#
#  'CODING ANT. POST. COMBINATION',
#
#  'LARGE Vs SMALL ARTERY',
#
#  'HAGE',
#
#  'NIHSS on discharge/MRS_codes_improved or not',
#
#  'complications_code',
#
#  'outcome',
#
#  'CAD ',
#
#  '2D ECHO',
#
#  'MRA (BRAIN/NECK)',
#
#  'CAROTID DOPPLER ',
#
#  'OTHER CO- MORBIDITY',
#
#  'ADDICTION',
#
#  'CODE SMOKER ',
#
#  'History of Stroke'

# %%
list(data.columns)
# Out:
# ['age_codes',
#  'Age',
#  'gender_code',
#  'Door to needle time ',
#  'door-door time_code',
#  'Neurological Deficit_code ',
#  'CODING WINDOW ',
#  'NIHSS on admission',
#  'NIHSS admission_code',
#  'MRS',
#  'Hyper tension ',
#  'DM',
#  'Blood Pressure at the time of admission',
#  'blood pressure_code',
#  'Blood Sugar at the time of admission (mg/dl)',
#  'blood sugar_code',
#  'CODING ANT. POST. COMBINATION',
#  'LARGE Vs SMALL ARTERY',
#  'HAGE',
#  ' Dose of Actilyse/ Weight(in gms)',
#  'NIHSS on admission.1',
#  'NIHSS on discharge/MRS_codes_improved or not',
#  'NIHSS after 1 hr',
#  '  NIHSS after 6 hrs',
#  'complications_code',
#  'outcome',
#  'CAD ',
#  '2D ECHO',
#  'MRA (BRAIN/NECK)',
#  'CAROTID DOPPLER ',
#  'OTHER CO- MORBIDITY',
#  'ADDICTION',
#  'CODE SMOKER ',
#  'History of Stroke']

# %% [markdown]
# # 4. EDA for various combinations

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Various [combinations](https://docs.google.com/document/d/1ND3dIxmF_rFt506NOdcqIb7UBV-ruxkL5161YDulQWk/edit)

# %% [markdown]
# ### 1. The first combinations

# %% [markdown]
# ### Correlation to check the [feasibility](https://docs.google.com/document/d/1MzNNIe3byQgMdWL5FxLqX2hHfhEWHEUwBEsAl0nOC2g/edit)

# %% [markdown]
# Correlation coefficient values below 0.3 are considered to be weak; 0.3-0.7 are moderate; >0.7 are strong

# %%
data.head(5)
# Out:
#    Unnamed: 0  age_codes   Age  ...  History of Stroke  systolic  diastolic
# 0           0        6.0  65.0  ...                2.0     150.0       80.0
# 1           1        3.0  38.0  ...                2.0     130.0       80.0
# 2           2        4.0  45.0  ...                2.0     160.0      100.0
# 3           3        5.0  50.0  ...                2.0     160.0      100.0
# 4           4        4.0  45.0  ...                2.0     160.0      100.0
#
# [5 rows x 35 columns]

# %%
cor=data.corr()
cor['NIHSS after 1 hr'].sort_values()
# Out:
# LARGE Vs SMALL ARTERY                          -0.294753
# systolic                                       -0.182363
# blood pressure_code                            -0.105854
# CODING ANT. POST. COMBINATION                  -0.103879
# ADDICTION                                      -0.091346
# CODING WINDOW                                  -0.072833
# DM                                             -0.058946
# Door to needle time                            -0.036079
# OTHER CO- MORBIDITY                            -0.035466
# blood sugar_code                               -0.013718
#  Dose of Actilyse/ Weight(in gms)              -0.001506
# diastolic                                       0.004014
# Unnamed: 0                                      0.011624
# History of Stroke                               0.012259
# CAROTID DOPPLER                                 0.039069
# door-door time_code                             0.040749
# ...

# %% [markdown]
# ## Graphical Univariate Analysis

# %%
data['outcome'].value_counts()
# Out:
# 1.0    121
# 2.0     19
# 3.0     10
# 4.0      4
# Name: outcome, dtype: int64

# %%
data['outcome'].hist(bins=25)
